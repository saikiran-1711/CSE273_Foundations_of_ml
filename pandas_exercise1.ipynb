# %%
import pandas as pd

# %%
#You are HR Data Analyst for "techCorp" you are provided with dataframe named df containing records.

# %%
Data ={
    'Name': ['sai', 'manin', 'ruthvik', 'harsh', 'ganesh', 'shivam', 'aman', 'amit', 'satyarth', 'satyam'],
    'Department': ['HR', 'sales', 'hr', 'it', 'sales', 'hr', 'it', 'sales', 'it', 'it'],
    'Role': ['HR', 'executive', 'executive', 'manager', 'executive', 'executive', 'manager', 'executive', 'executive', 'manager'],
    'Experience' : [5, 2, 3, 6, 1, 4, 7, 2, 3, 5],
    'Salary': [80000, 50000, 60000, 90000, 45000, 70000, 100000, 55000, 65000, 85000],
    'Score': [85, 70, 75, None, 70, 65, None,  72, 78, 88],
}

# %%
df = pd.DataFrame(Data)

# %% [markdown]
# 2. write code to answer mean of salary for each department
# 3. what is average performance score for each role?

# %%
average_salary = df['Salary'].mean()
print(average_salary)
average_performance = df['Score'].mean()
print(average_performance)
#check how many non nulll performance scores are there in each dept
#total no of employee records(rows) in each dept 
performance_by_dept = df.groupby('Department')['Score'].mean()
print(performance_by_dept)
score_counts = df['Score'].value_counts()
print(score_counts)
dept_counts = df['Department'].value_counts()
print(dept_counts)
# Out:
# 70000.0
# 73.3
# Department
# HR       85.000000
# hr       70.000000
# it       74.000000
# sales    70.666667
# Name: Score, dtype: float64
# Score
# 70    2
# 85    1
# 75    1
# 50    1
# 65    1
# 80    1
# 72    1
# 78    1
# 88    1
# Name: count, dtype: int64
# Department
# it       4
# sales    3
# hr       2
# HR       1
# Name: count, dtype: int64

# %%
#generate a summary table for salary based on dept showing mena max min and count in single line of code
#generate same but analyse the perfor
